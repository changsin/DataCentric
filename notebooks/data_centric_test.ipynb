# %% [markdown]
# <a href="https://colab.research.google.com/github/changsin/DataCentric/blob/main/notebooks/data_centric_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Centric Competition
#
# ## Overview
# Data Centric Competition is the first AI competition where you focus exclusively on manipulating the datasets instead of models. It is organized by DeepLearning.AI and here are the links:
#
# - [main page](https://https-deeplearning-ai.github.io/data-centric-comp/?utm_source=thebatch&utm_medium=newsletter&utm_campaign=dc-ai-competition&utm_content=dl-ai)
# - [Guidelines](https://worksheets.codalab.org/worksheets/0x7a8721f11e61436e93ac8f76da83f0e6)
# - [CodaLab](https://codalab-worksheets.readthedocs.io/en/latest/): this is the workspace where you create a worksheet, build datasets, etc.
#
# The data consists of handwritten Roman numerals `i` through `x`. Zero was not invented in Roman times so no zeros.
#
# Three datasets are provided in three folders: namely, train, val, and label_book. Two python scripts were given as starters:
# - convert.py: a sample code to load images and resize
# - train.py: a sample code to load the datasets and train the model.
#
# ## Goal
# The goal is to train ResNet50 model with the training data and get a high accuracy.

# %% [markdown]
# ## Datasets
# The initial survey of the datasets is as follows:
#
# - Training set: 2067 color images with the shape (232, 232, 3)
# - Validation set: 813 iamges
# - Test set (label_book):
#
# The labels are provided by the folder name: e.g., 'i' has all the images of i, etc.

# %% [markdown]
# ## EDA
# The convert method provided converts the image to grayscale and quantizes for easier processing. The size is also reduced to 32x32. This makes the resulting image quite distorted in some cases. For instance, one image of 'iv' looks something between 'iii' and 'iv'

# %% [markdown]
# ![Screen Shot 2021-07-03 at 11.42.35 PM.png](data:image/png;base64,...)

# %% [markdown]
# PCA and Clustering of the training set shows quite overlapped features. This explains poor test results from the default model: 51.92%

# %% [markdown]
# ![Screen Shot 2021-07-03 at 11.46.11 PM.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import os
import glob

DATA_ROOT = "./drive/MyDrive/data/DataCentric/"
CLASS_NAMES = ["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"]
IMAGE_SIZE = 32
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ##### log path is /content #####

# %%
def glob_files(path):
    search_string = os.path.join(path,'*')
    files = glob.glob(search_string)

    # print('searching ', path)
    paths = []
    for f in files:
      if os.path.isdir(f):
        sub_paths = glob_files(f + '/')
        paths += sub_paths
      else:
        paths.append(f)

    # We sort the images in alphabetical order to match them
    #  to the annotation files
    paths.sort()

    return paths

# %%
import cv2


def load_images(path):
  paths = glob_files(path)

  X_raw = []
  for file in paths:
    image = cv2.imread(file)
    image = cv2.resize(image, (IMAGE_SIZE,IMAGE_SIZE))
    X_raw.append(np.array(image))

  return np.array(X_raw)

X_train_raw = load_images(DATA_ROOT + 'train/')

# %% [markdown]
# ## Convert to grayscale and normalize
# Since the images are handwritten Roman numerals in white background, it is better to convert them to grayscale and then normalize to reduce the features

# %%
# # official convert_images method
# def convert_images(input_folder, output_folder):
#     Path(output_folder).mkdir(parents=True, exist_ok=True)
#     input_files = glob(os.path.join(input_folder, "*.png"))
#     for f in input_files:
#         image = cv2.imread(f, cv2.IMREAD_GRAYSCALE)
#         # quantize
#         image = (image // 43) * 43
#         image[image > 43] = 255
#         cv2.imwrite(os.path.join(output_folder, os.path.basename(f)), image)

# %%
def quantize(X):
  quantized = []
  for x in X:
    x = (x // 43) * 43
    x[x > 43] = 255
    quantized.append(x)

  return np.array(quantized)

# %%
X_train_gray = np.array([cv2.cvtColor(x, cv2.COLOR_BGR2GRAY) for x in X_train_raw])

X_train_quantized = quantize(X_train_gray)
X_train = X_train_quantized / 255.0

# %% [markdown]
# ## Load Validation data

# %%
def prepare_data(path):
  X_raw = load_images(path)
  X_gray = np.array([cv2.cvtColor(x, cv2.COLOR_BGR2GRAY) for x in X_raw])

  X_quantized = quantize(X_gray)
  X = X_quantized / 255.0

  return X

X_val = prepare_data(DATA_ROOT + 'val/')

# %%
Y_val = load_labels(DATA_ROOT + 'val/')
Y_val.shape
# Out:
# (813,)

# %%
plot_data(X_val, Y_val)

# %%
LABELS = [ 'i', 'ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii', 'ix', 'x']

def load_labels(path):
  paths = glob_files(path)

  Y = []
  for file in paths:
    y = file.split('/')[-2]
    id = LABELS.index(y)
    Y.append(id)

  return np.array(Y)

Y_train = load_labels(DATA_ROOT + 'train/')

# %% [markdown]
# ## Load test data

# %%
X_test = prepare_data(DATA_ROOT + 'label_book/')
Y_test = load_labels(DATA_ROOT + 'label_book/')
plot_data(X_test, Y_test)
X_test.shape

# %%
def plot_data(X, Y, limit=20):
  fig = plt.figure(figsize=(20,40))

  # The number of images for plotting is limited to 50
  end_id = len(Y) if len(Y) < limit else limit

  for i in range(0, end_id):
    axis = fig.add_subplot(10, 5, i+1)
    plt.axis('off')
    image = X[i]

    axis.set_title(Y[i])
    axis.imshow(np.clip(image, 0, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1912e8ed4071> in <module>()
#      13     axis.imshow(np.clip(image, 0, 1))
#      14
# ---> 15 plot_data(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
plot_data(X_train, Y_train)

# %% [markdown]
# # Train
# The default training run results in:
#
# training accuracy: 99.37%
# validation accuracy: 65.31%
# test accuracy: 51.92%
#
# ```
# Epoch 100/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 1.3546 - val_accuracy: 0.6531
# 102/102 [==============================] - 1s 8ms/step - loss: 1.3027 - accuracy: 0.6691
# final loss 1.3026752471923828, final acc 0.6691266894340515
# 7/7 [==============================] - 6s 725ms/step - loss: 2.2927 - accuracy: 0.5192
# test loss 2.2927401065826416, test acc 0.5192307829856873
# ```

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import json
import sys

train_data_path = DATA_ROOT + "/train"
valid_data_path = DATA_ROOT + "/val"
test_data_path = DATA_ROOT + "/label_book" # this can be the label book, or any other test set you create

### DO NOT MODIFY BELOW THIS LINE, THIS IS THE FIXED MODEL ###
batch_size = 8
tf.random.set_seed(123)

def load_data(train_data_path, val_data_path, test_data_path):
  train_data = tf.keras.preprocessing.image_dataset_from_directory(
      train_data_path,
      labels="inferred",
      label_mode="categorical",
      class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
      shuffle=True,
      seed=123,
      batch_size=batch_size,
      image_size=(32, 32),
  )

  val_data = tf.keras.preprocessing.image_dataset_from_directory(
      val_data_path,
      labels="inferred",
      label_mode="categorical",
      class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
      shuffle=True,
      seed=123,
      batch_size=batch_size,
      image_size=(32, 32),
  )

  total_length = ((train_data.cardinality() + val_data.cardinality()) * batch_size).numpy()
  if total_length > 10_000:
      print(f"Dataset size larger than 10,000. Got {total_length} examples")
      sys.exit()

  test_data = tf.keras.preprocessing.image_dataset_from_directory(
      test_data_path,
      labels="inferred",
      label_mode="categorical",
      class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
      shuffle=False,
      seed=123,
      batch_size=batch_size,
      image_size=(32, 32),
  )

  return train_data, val_data, test_data

# %%
def train(train_data, val_data, test_data):
  base_model = tf.keras.applications.ResNet50(
      input_shape=(32, 32, 3),
      include_top=False,
      weights=None,
  )
  base_model = tf.keras.Model(
      base_model.inputs, outputs=[base_model.get_layer("conv2_block3_out").output]
  )

  inputs = tf.keras.Input(shape=(32, 32, 3))
  x = tf.keras.applications.resnet.preprocess_input(inputs)
  x = base_model(x)
  x = tf.keras.layers.GlobalAveragePooling2D()(x)
  x = tf.keras.layers.Dense(10)(x)
  model = tf.keras.Model(inputs, x)

  model.compile(
      optimizer=tf.keras.optimizers.Adam(lr=0.0001),
      loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
      metrics=["accuracy"],
  )
  model.summary()
  loss_0, acc_0 = model.evaluate(val_data)
  print(f"loss {loss_0}, acc {acc_0}")

  checkpoint = tf.keras.callbacks.ModelCheckpoint(
      "best_model",
      monitor="val_accuracy",
      mode="max",
      save_best_only=True,
      save_weights_only=True,
  )

  history = model.fit(
      train_data,
      validation_data=val_data,
      epochs=100,
      callbacks=[checkpoint],
  )

  model.load_weights("best_model")

  loss, acc = model.evaluate(val_data)
  print(f"final loss {loss}, final acc {acc}")

  test_loss, test_acc = model.evaluate(test_data)
  print(f"test loss {test_loss}, test acc {test_acc}")

  return model

# %%
train_data, val_data, test_data = load_data(DATA_ROOT + "train", DATA_ROOT + "val", DATA_ROOT + "label_book")
model_base = train(train_data, val_data, test_data)
# Out:
# Found 2067 files belonging to 10 classes.
# Found 813 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# tf.__operators__.getitem_1 ( (None, 32, 32, 3)         0
# _________________________________________________________________
# tf.nn.bias_add_1 (TFOpLambda (None, 32, 32, 3)         0
# _________________________________________________________________
# model_2 (Functional)         (None, 8, 8, 256)         229760
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 232,330
# Trainable params: 229,386
# Non-trainable params: 2,944
# _________________________________________________________________
# 102/102 [==============================] - 1s 7ms/step - loss: 36.5970 - accuracy: 0.0996
# loss 36.59703826904297, acc 0.09963099658489227
# Epoch 1/100
# 259/259 [==============================] - 5s 14ms/step - loss: 2.0614 - accuracy: 0.2864 - val_loss: 2.1112 - val_accuracy: 0.1747
# Epoch 2/100
# 259/259 [==============================] - 4s 14ms/step - loss: 1.5282 - accuracy: 0.5012 - val_loss: 1.4876 - val_accuracy: 0.5166
# Epoch 3/100
# 259/259 [==============================] - 4s 14ms/step - loss: 1.2362 - accuracy: 0.6130 - val_loss: 1.2901 - val_accuracy: 0.5461
# Epoch 4/100
# 259/259 [==============================] - 4s 14ms/step - loss: 1.0349 - accuracy: 0.6851 - val_loss: 1.2296 - val_accuracy: 0.5510
# Epoch 5/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.8887 - accuracy: 0.7329 - val_loss: 1.1000 - val_accuracy: 0.6162
# Epoch 6/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.7853 - accuracy: 0.7581 - val_loss: 1.0129 - val_accuracy: 0.6396
# Epoch 7/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.6990 - accuracy: 0.7944 - val_loss: 1.2024 - val_accuracy: 0.5547
# Epoch 8/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.5626 - accuracy: 0.8413 - val_loss: 1.1094 - val_accuracy: 0.6101
# Epoch 9/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.5071 - accuracy: 0.8607 - val_loss: 1.2646 - val_accuracy: 0.5609
# Epoch 10/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.4456 - accuracy: 0.8820 - val_loss: 1.4393 - val_accuracy: 0.5105
# Epoch 11/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.4045 - accuracy: 0.8911 - val_loss: 1.7059 - val_accuracy: 0.4563
# Epoch 12/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.3321 - accuracy: 0.9134 - val_loss: 1.0908 - val_accuracy: 0.6335
# Epoch 13/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.2753 - accuracy: 0.9332 - val_loss: 1.3841 - val_accuracy: 0.5806
# Epoch 14/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.2356 - accuracy: 0.9473 - val_loss: 1.1137 - val_accuracy: 0.6347
# Epoch 15/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.1941 - accuracy: 0.9589 - val_loss: 1.7455 - val_accuracy: 0.5117
# Epoch 16/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1887 - accuracy: 0.9598 - val_loss: 1.7733 - val_accuracy: 0.5215
# Epoch 17/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1525 - accuracy: 0.9700 - val_loss: 1.5565 - val_accuracy: 0.5523
# Epoch 18/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1440 - accuracy: 0.9690 - val_loss: 1.3332 - val_accuracy: 0.6076
# Epoch 19/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1227 - accuracy: 0.9768 - val_loss: 1.5111 - val_accuracy: 0.5929
# Epoch 20/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1095 - accuracy: 0.9811 - val_loss: 1.5128 - val_accuracy: 0.5769
# Epoch 21/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1150 - accuracy: 0.9763 - val_loss: 2.3495 - val_accuracy: 0.4736
# Epoch 22/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1103 - accuracy: 0.9753 - val_loss: 1.4408 - val_accuracy: 0.5916
# Epoch 23/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0959 - accuracy: 0.9816 - val_loss: 1.8883 - val_accuracy: 0.5338
# Epoch 24/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0896 - accuracy: 0.9831 - val_loss: 1.9044 - val_accuracy: 0.5424
# Epoch 25/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0820 - accuracy: 0.9816 - val_loss: 2.0356 - val_accuracy: 0.5105
# Epoch 26/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0856 - accuracy: 0.9831 - val_loss: 2.1055 - val_accuracy: 0.5301
# Epoch 27/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0854 - accuracy: 0.9821 - val_loss: 1.5001 - val_accuracy: 0.6212
# Epoch 28/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0849 - accuracy: 0.9797 - val_loss: 2.0737 - val_accuracy: 0.5092
# Epoch 29/100
# 259/259 [==============================] - 4s 17ms/step - loss: 0.0672 - accuracy: 0.9865 - val_loss: 1.6145 - val_accuracy: 0.5855
# Epoch 30/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0717 - accuracy: 0.9850 - val_loss: 1.6255 - val_accuracy: 0.5707
# Epoch 31/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0771 - accuracy: 0.9816 - val_loss: 2.5225 - val_accuracy: 0.4908
# Epoch 32/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0584 - accuracy: 0.9884 - val_loss: 1.9543 - val_accuracy: 0.5461
# Epoch 33/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0496 - accuracy: 0.9918 - val_loss: 1.7533 - val_accuracy: 0.5843
# Epoch 34/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.
100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0575 - accuracy: 0.9831 - val_loss: 1.9928 - val_accuracy: 0.5941
# Epoch 96/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0254 - accuracy: 0.9937 - val_loss: 1.5569 - val_accuracy: 0.6507
# Epoch 97/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0444 - accuracy: 0.9879 - val_loss: 3.2345 - val_accuracy: 0.5461
# Epoch 98/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0230 - accuracy: 0.9961 - val_loss: 1.5001 - val_accuracy: 0.6568
# Epoch 99/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 1.4450 - val_accuracy: 0.6556
# Epoch 100/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0198 - accuracy: 0.9971 - val_loss: 2.8098 - val_accuracy: 0.5228
# 102/102 [==============================] - 1s 7ms/step - loss: 1.5001 - accuracy: 0.6568
# final loss 1.5001493692398071, final acc 0.6568265557289124
# 7/7 [==============================] - 3s 433ms/step - loss: 1.4708 - accuracy: 0.7115
# test loss 1.4707872867584229, test acc 0.7115384340286255

# %%
model_base.save_weights('model_base_weights.h5')
model_base.save('model_base.pb')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: model_base.pb/assets

# %%
train_data_1, val_data_1, test_data_1 = load_data(DATA_ROOT + "train_1", DATA_ROOT + "val_1", DATA_ROOT + "label_book_1")
model_1 = train(train_data_1, val_data_1, test_data_1)
# Out:
# Found 2067 files belonging to 10 classes.
# Found 813 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# tf.__operators__.getitem_2 ( (None, 32, 32, 3)         0
# _________________________________________________________________
# tf.nn.bias_add_2 (TFOpLambda (None, 32, 32, 3)         0
# _________________________________________________________________
# model_4 (Functional)         (None, 8, 8, 256)         229760
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 232,330
# Trainable params: 229,386
# Non-trainable params: 2,944
# _________________________________________________________________
# 102/102 [==============================] - 48s 427ms/step - loss: 85.7784 - accuracy: 0.1021
# loss 85.77841186523438, acc 0.10209102183580399
# Epoch 1/100
# 259/259 [==============================] - 122s 452ms/step - loss: 2.1075 - accuracy: 0.2806 - val_loss: 2.2414 - val_accuracy: 0.1734
# Epoch 2/100
# 259/259 [==============================] - 4s 14ms/step - loss: 1.4890 - accuracy: 0.5167 - val_loss: 1.6476 - val_accuracy: 0.4121
# Epoch 3/100
# 259/259 [==============================] - 4s 13ms/step - loss: 1.2193 - accuracy: 0.6168 - val_loss: 1.3810 - val_accuracy: 0.5572
# Epoch 4/100
# 259/259 [==============================] - 4s 13ms/step - loss: 1.0269 - accuracy: 0.6783 - val_loss: 1.4267 - val_accuracy: 0.5338
# Epoch 5/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.8820 - accuracy: 0.7218 - val_loss: 1.1367 - val_accuracy: 0.6285
# Epoch 6/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.7786 - accuracy: 0.7504 - val_loss: 1.2860 - val_accuracy: 0.5154
# Epoch 7/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.6912 - accuracy: 0.7939 - val_loss: 1.1613 - val_accuracy: 0.5966
# Epoch 8/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.5583 - accuracy: 0.8413 - val_loss: 1.2632 - val_accuracy: 0.5683
# Epoch 9/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.4989 - accuracy: 0.8587 - val_loss: 1.2552 - val_accuracy: 0.5535
# Epoch 10/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.4381 - accuracy: 0.8786 - val_loss: 1.2155 - val_accuracy: 0.5584
# Epoch 11/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.3884 - accuracy: 0.8945 - val_loss: 1.0897 - val_accuracy: 0.6371
# Epoch 12/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.3353 - accuracy: 0.9149 - val_loss: 1.0631 - val_accuracy: 0.6531
# Epoch 13/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.2643 - accuracy: 0.9424 - val_loss: 1.2958 - val_accuracy: 0.5879
# Epoch 14/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.2376 - accuracy: 0.9453 - val_loss: 1.1878 - val_accuracy: 0.6224
# Epoch 15/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1958 - accuracy: 0.9584 - val_loss: 1.2205 - val_accuracy: 0.6064
# Epoch 16/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1973 - accuracy: 0.9584 - val_loss: 1.7045 - val_accuracy: 0.5338
# Epoch 17/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1540 - accuracy: 0.9700 - val_loss: 1.2610 - val_accuracy: 0.6027
# Epoch 18/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1571 - accuracy: 0.9657 - val_loss: 1.7303 - val_accuracy: 0.5572
# Epoch 19/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1345 - accuracy: 0.9763 - val_loss: 1.3523 - val_accuracy: 0.5953
# Epoch 20/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1231 - accuracy: 0.9763 - val_loss: 1.5542 - val_accuracy: 0.5510
# Epoch 21/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1208 - accuracy: 0.9768 - val_loss: 1.5776 - val_accuracy: 0.5621
# Epoch 22/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0985 - accuracy: 0.9802 - val_loss: 1.2653 - val_accuracy: 0.6359
# Epoch 23/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.1030 - accuracy: 0.9782 - val_loss: 1.4563 - val_accuracy: 0.6298
# Epoch 24/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0911 - accuracy: 0.9845 - val_loss: 1.5121 - val_accuracy: 0.6064
# Epoch 25/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0858 - accuracy: 0.9816 - val_loss: 2.1608 - val_accuracy: 0.5597
# Epoch 26/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0944 - accuracy: 0.9792 - val_loss: 1.8140 - val_accuracy: 0.5252
# Epoch 27/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0881 - accuracy: 0.9831 - val_loss: 2.0555 - val_accuracy: 0.5191
# Epoch 28/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0925 - accuracy: 0.9802 - val_loss: 1.2987 - val_accuracy: 0.6162
# Epoch 29/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0646 - accuracy: 0.9889 - val_loss: 1.7066 - val_accuracy: 0.5781
# Epoch 30/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0661 - accuracy: 0.9865 - val_loss: 1.7457 - val_accuracy: 0.5584
# Epoch 31/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.0741 - accuracy: 0.9865 - val_loss: 2.1750 - val_accuracy: 0.5240
# Epoch 32/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0569 - accuracy: 0.9898 - val_loss: 1.3018 - val_accuracy: 0.6421
# Epoch 33/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0580 - accuracy: 0.9889 - val_loss: 1.7212 - val_accuracy: 0.6027
# Epoch 34/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0591 - accuracy: 0.9869 - val_loss: 1.8366 - val_accuracy: 0.5437
# Epoch 35/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0600 - accuracy: 0.9869 - val_loss: 1.8190 - val_accuracy: 0.5843
# Epoch 36/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0799 - accuracy: 0.9811 - val_loss: 1.8915 - val_accuracy: 0.5769
# Epoch 37/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.0579 - accuracy: 0.9874 - val_loss: 2.2768 - val_accuracy: 0.5154
# Epoch 38/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0497 - accuracy: 0.9894 - val_loss: 1.9111 - val_accuracy: 0.5400
# Epoch 39/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0447 - accuracy: 0.9913 - val_loss: 1.9262 - val_accuracy: 0.5523
# Epoch 40/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0348 - accuracy: 0.9923 - val_loss: 1.6059 - val_accuracy: 0.6089
# Epoch 41/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0488 - accuracy: 0.9879 - val_loss: 2.3900 - val_accuracy: 0.5301
# Epoch 42/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0662 - accuracy: 0.9816 - val_loss: 1.3831 - val_accuracy: 0.6371
# Epoch 43/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0451 - accuracy: 0.9894 - val_loss: 2.0242 - val_accuracy: 0.5375
# Epoch 44/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0357 - accuracy: 0.9932 - val_loss: 2.0346 - val_accuracy: 0.5510
# Epoch 45/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0371 - accuracy: 0.9918 - val_loss: 1.5370 - val_accuracy: 0.5966
# Epoch 46/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0514 - accuracy: 0.9879 - val_loss: 1.4604 - val_accuracy: 0.6150
# Epoch 47/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0509 - accuracy: 0.9903 - val_loss: 1.4704 - val_accuracy: 0.6298
# Epoch 48/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0493 - accuracy: 0.9894 - val_loss: 2.2607 - val_accuracy: 0.5338
# Epoch 49/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0404 - accuracy: 0.9913 - val_loss: 1.9172 - val_accuracy: 0.5547
# Epoch 50/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0489 - accuracy: 0.9898 - val_loss: 2.1756 - val_accuracy: 0.5486
# Epoch 51/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.0506 - accuracy: 0.9869 - val_loss: 1.6882 - val_accuracy: 0.6199
# Epoch 52/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0278 - accuracy: 0.9932 - val_loss: 2.3050 - val_accuracy: 0.5584
# Epoch 53/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0243 - accuracy: 0.9971 - val_loss: 1.4994 - val_accuracy: 0.6187
# Epoch 54/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.0334 - accuracy: 0.9932 - val_loss: 1.7295 - val_accuracy: 0.6002
# Epoch 55/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0456 - accuracy: 0.9889 - val_loss: 1.9661 - val_accuracy: 0.5879
# Epoch 56/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0231 - accuracy: 0.9971 - val_loss: 2.0688 - val_accuracy: 0.5621
# Epoch 57/100
# 259/259 [==============================] - 3s 13ms/step - loss: 0.0346 - accuracy: 0.9913 - val_loss: 1.6234 - val_accuracy: 0.6224
# Epoch 58/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.0539 - accuracy: 0.9855 - val_loss: 3.5757 - val_accuracy: 0.4490
# Epoch 59/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0373 - accuracy: 0.9894 - val_loss: 1.3606 - val_accuracy: 0.6445
# Epoch 60/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0436 - accuracy: 0.9889 - val_loss: 1.5174 - val_accuracy: 0.6544
# Epoch 61/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0284 - accuracy: 0.9937 - val_loss: 1.8378 - val_accuracy: 0.6015
# Epoch 62/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0408 - accuracy: 0.9913 - val_loss: 1.6746 - val_accuracy: 0.5806
# Epoch 63/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0558 - accuracy: 0.9850 - val_loss: 1.9352 - val_accuracy: 0.5818
# Epoch 64/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0292 - accuracy: 0.9918 - val_loss: 1.6729 - val_accuracy: 0.6371
# Epoch 65/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0333 - accuracy: 0.9932 - val_loss: 1.9768 - val_accuracy: 0.5658
# Epoch 66/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0205 - accuracy: 0.9952 - val_loss: 1.4577 - val_accuracy: 0.6507
# Epoch 67/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0380 - accuracy: 0.9913 - val_loss: 2.1559 - val_accuracy: 0.5633
# Epoch 68/100
# 259/259 [==============================] - 4s 14ms/step - loss: 0.0343 - accuracy: 0.9903 - val_loss: 3.4108 - val_accuracy: 0.4809
# Epoch 69/100
# 259/259 [==============================] - 4s 13ms/step - loss: 0.
100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 1.7111 - val_accuracy: 0.6125
# Epoch 99/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0288 - accuracy: 0.9932 - val_loss: 1.8216 - val_accuracy: 0.6002
# Epoch 100/100
# 259/259 [==============================] - 4s 15ms/step - loss: 0.0282 - accuracy: 0.9937 - val_loss: 1.6774 - val_accuracy: 0.6187
# 102/102 [==============================] - 1s 8ms/step - loss: 1.5174 - accuracy: 0.6544
# final loss 1.5173577070236206, final acc 0.6543665528297424
# 7/7 [==============================] - 5s 645ms/step - loss: 1.9829 - accuracy: 0.5962
# test loss 1.9829131364822388, test acc 0.5961538553237915

# %%
import tensorflow as tf

model_base = tf.keras.models.load_model(DATA_ROOT + 'model_base.pb')
model_1 = tf.keras.models.load_model(DATA_ROOT + 'model_1.pb')

# %%
train_data, val_data, test_data = load_data(DATA_ROOT + "train", DATA_ROOT + "val", DATA_ROOT + "label_book")

predictions = model_base.predict(test_data)
# Out:
# Found 2067 files belonging to 10 classes.
# Found 813 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.

# %%
train_data_1, val_data_1, test_data_1 = load_data(DATA_ROOT + "train_1", DATA_ROOT + "val_1", DATA_ROOT + "label_book_1")

predictions_1 = model_base.predict(test_data_1)
# Out:
# Found 2067 files belonging to 10 classes.
# Found 813 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.

# %%
train_data_ttc, val_data, test_data = load_data(DATA_ROOT + "ttc", DATA_ROOT + "val", DATA_ROOT + "label_book")
model_ttc = train(train_data_ttc, val_data, test_data)
# Out:
# Found 440 files belonging to 10 classes.
# Found 813 files belonging to 10 classes.
# Found 52 files belonging to 10 classes.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# tf.__operators__.getitem (Sl (None, 32, 32, 3)         0
# _________________________________________________________________
# tf.nn.bias_add (TFOpLambda)  (None, 32, 32, 3)         0
# _________________________________________________________________
# model (Functional)           (None, 8, 8, 256)         229760
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# =================================================================
# Total params: 232,330
# Trainable params: 229,386
# Non-trainable params: 2,944
# _________________________________________________________________
# 102/102 [==============================] - 78s 694ms/step - loss: 31.4126 - accuracy: 0.1009
# loss 31.412607192993164, acc 0.10086100548505783
# Epoch 1/100
# 55/55 [==============================] - 39s 533ms/step - loss: 2.3893 - accuracy: 0.2409 - val_loss: 2.9106 - val_accuracy: 0.0972
# Epoch 2/100
# 55/55 [==============================] - 1s 23ms/step - loss: 1.6371 - accuracy: 0.5136 - val_loss: 2.3936 - val_accuracy: 0.0947
# Epoch 3/100
# 55/55 [==============================] - 1s 23ms/step - loss: 1.2415 - accuracy: 0.6250 - val_loss: 2.1892 - val_accuracy: 0.1697
# Epoch 4/100
# 55/55 [==============================] - 1s 23ms/step - loss: 0.9679 - accuracy: 0.7000 - val_loss: 2.1092 - val_accuracy: 0.2448
# Epoch 5/100
# 55/55 [==============================] - 1s 23ms/step - loss: 0.8321 - accuracy: 0.7045 - val_loss: 2.2712 - val_accuracy: 0.2460
# Epoch 6/100
# 55/55 [==============================] - 1s 24ms/step - loss: 0.6862 - accuracy: 0.7614 - val_loss: 2.4608 - val_accuracy: 0.2263
# Epoch 7/100
# 55/55 [==============================] - 1s 23ms/step - loss: 0.6429 - accuracy: 0.7591 - val_loss: 2.7271 - val_accuracy: 0.2276
# Epoch 8/100
# 55/55 [==============================] - 1s 23ms/step - loss: 0.5800 - accuracy: 0.7545 - val_loss: 2.9398 - val_accuracy: 0.2349
# Epoch 9/100
# 55/55 [==============================] - 1s 24ms/step - loss: 0
100
# 55/55 [==============================] - 1s 25ms/step - loss: 0.3083 - accuracy: 0.8114 - val_loss: 3.0037 - val_accuracy: 0.2669
# Epoch 99/100
# 55/55 [==============================] - 1s 26ms/step - loss: 0.3089 - accuracy: 0.8114 - val_loss: 2.8015 - val_accuracy: 0.2755
# Epoch 100/100
# 55/55 [==============================] - 1s 25ms/step - loss: 0.3123 - accuracy: 0.8136 - val_loss: 2.9452 - val_accuracy: 0.2768
# 102/102 [==============================] - 1s 8ms/step - loss: 2.9452 - accuracy: 0.2768
# final loss 2.9452197551727295, final acc 0.276752769947052
# 7/7 [==============================] - 0s 7ms/step - loss: 3.6024 - accuracy: 0.2500
# test loss 3.6024465560913086, test acc 0.25

# %%
predictions_ttc = model_ttc.predict(test_data)

# %%
actual = [np.argmax(pred) for pred in predictions]
# actual_1 = [np.argmax(pred) for pred in predictions_1]
actual_ttc = [np.argmax(pred) for pred in predictions_ttc]

# %%
expected = [np.argmax(y) for _, Y in test_data for y in Y]

# %%
from collections import Counter

Counter(actual)
# Out:
# Counter({0: 8, 1: 5, 2: 7, 3: 7, 4: 6, 5: 5, 6: 2, 7: 5, 8: 3, 9: 4})

# %%
def extract_images(dataset):
  images = []
  for X, Y in dataset:
    for x in X:
      images.append(x)

  return images

test_images = extract_images(test_data)

# %%
def calc_accuracy_per_class(expected, actual, images):

  corrects = {}
  for i in range(len(CLASS_NAMES)):
    corrects[i] = 0

  cur_digit_id = 0
  prev_digit = 0
  for id, a, e in zip(range(len(actual)), actual, expected):
    if a == e:
      corrects[a] = corrects[a] + 1
    else:
      print("{} {} Expected: {} Actual: {}".format(id, cur_digit_id, e, a))
      if e == 2:
        plot_data([images[id]], [e])
    
    if e == prev_digit:
      cur_digit_id += 1
    else:
      cur_digit_id = 1
    prev_digit = e

  accuracy_results = []
  for key, true_pos in corrects.items():
    # print(key, true_pos)
    if true_pos > 0:
      accuracy_results.append(float(true_pos/actual.count(key)))
    else:
      accuracy_results.append(0)

  return accuracy_results

# %%
calc_accuracy_per_class(expected, actual, test_images)
# Out:
# 8 3 Expected: 1 Actual: 2
# 10 5 Expected: 2 Actual: 7
# 11 1 Expected: 2 Actual: 1
# 12 2 Expected: 2 Actual: 3
# 13 3 Expected: 2 Actual: 3
# 16 6 Expected: 3 Actual: 4
# 23 2 Expected: 8 Actual: 3
# 25 4 Expected: 8 Actual: 5
# 28 2 Expected: 4 Actual: 0
# 32 6 Expected: 5 Actual: 0
# 37 5 Expected: 6 Actual: 2
# 38 1 Expected: 6 Actual: 2
# 41 4 Expected: 6 Actual: 2
# 45 3 Expected: 7 Actual: 2
# 51 4 Expected: 9 Actual: 0
# [0.625,
#  0.8,
#  0.2857142857142857,
#  0.5714285714285714,
#  0.8333333333333334,
#  0.8,
#  1.0,
#  0.8,
#  1.0,
#  1.0]

# %%
calc_accuracy_per_class(expected, actual_ttc, test_images)
# Out:
# 0 0 Expected: 0 Actual: 3
# 1 1 Expected: 0 Actual: 1
# 2 2 Expected: 0 Actual: 1
# 4 4 Expected: 0 Actual: 8
# 5 5 Expected: 1 Actual: 3
# 6 1 Expected: 1 Actual: 5
# 7 2 Expected: 1 Actual: 8
# 8 3 Expected: 1 Actual: 5
# 10 5 Expected: 2 Actual: 0
# 12 2 Expected: 2 Actual: 0
# 13 3 Expected: 2 Actual: 4
# 15 5 Expected: 2 Actual: 5
# 16 6 Expected: 3 Actual: 9
# 18 2 Expected: 3 Actual: 9
# 21 5 Expected: 8 Actual: 5
# 22 1 Expected: 8 Actual: 3
# 23 2 Expected: 8 Actual: 3
# 24 3 Expected: 8 Actual: 9
# 25 4 Expected: 8 Actual: 9
# 26 5 Expected: 4 Actual: 1
# 27 1 Expected: 4 Actual: 9
# 28 2 Expected: 4 Actual: 3
# 29 3 Expected: 4 Actual: 1
# 30 4 Expected: 4 Actual: 0
# 32 6 Expected: 5 Actual: 3
# 36 4 Expected: 5 Actual: 3
# 37 5 Expected: 6 Actual: 1
# 38 1 Expected: 6 Actual: 5
# 39 2 Expected: 6 Actual: 5
# 40 3 Expected: 6 Actual: 3
# 41 4 Expected: 6 Actual: 1
# 42 5 Expected: 7 Actual: 0
# 43 1 Expected: 7 Actual: 3
# 44 2 Expected: 7 Actual: 8
# 45 3 Expected: 7 Actual: 1
# 46 4 Expected: 7 Actual: 3
# 47 5 Expected: 9 Actual: 1
# 48 1 Expected: 9 Actual: 0
# 51 4 Expected: 9 Actual: 8
# [0.16666666666666666,
#  0.1111111111111111,
#  1.0,
#  0.23076923076923078,
#  0.5,
#  0.3333333333333333,
#  0,
#  0,
#  0,
#  0.2857142857142857]

# %%
calc_accuracy_per_class(expected, actual_1)
# Out:
# Expected: 1 Actual: 2
# Expected: 2 Actual: 7
# Expected: 2 Actual: 1
# Expected: 2 Actual: 3
# Expected: 2 Actual: 3
# Expected: 3 Actual: 4
# Expected: 8 Actual: 3
# Expected: 8 Actual: 5
# Expected: 4 Actual: 0
# Expected: 5 Actual: 0
# Expected: 6 Actual: 2
# Expected: 6 Actual: 2
# Expected: 6 Actual: 2
# Expected: 7 Actual: 6
# Expected: 9 Actual: 0
# [0.625,
#  0.8,
#  0.3333333333333333,
#  0.5714285714285714,
#  0.8333333333333334,
#  0.8,
#  0.6666666666666666,
#  0.8,
#  1.0,
#  1.0]

# %%
def enumerate_dataset(dataset):
  for X, Y in dataset:
    # print(Y.shape)
    for y in Y:
      print(np.argmax(y))

# %%
amodel_1.save_weights('model_1_weights.h5')
model_1.save('model_1.pb')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: model_1.pb/assets

# %% [markdown]
# # Experiment 1: Synthetic data
# - Used ttc font files in Windows to generate synthetic data for training.
# - the result is abysmal. The model failed to converge and did worse than the base line
#
# ```
# 55/55 [==============================] - 1s 25ms/step - loss: 0.3123 - accuracy: 0.8136 - val_loss: 2.9452 - val_accuracy: 0.2768
# 102/102 [==============================] - 1s 8ms/step - loss: 2.9452 - accuracy: 0.2768
# final loss 2.9452197551727295, final acc 0.276752769947052
# 7/7 [==============================] - 0s 7ms/step - loss: 3.6024 - accuracy: 0.2500
# test loss 3.6024465560913086, test acc 0.25
# ```
#
# ```
#  0.16666666666666666,
#  0.1111111111111111,
#  1.0,
#  0.23076923076923078,
#  0.5,
#  0.3333333333333333,
#  0,
#  0,
#  0,
#  0.2857142857142857
# ```
